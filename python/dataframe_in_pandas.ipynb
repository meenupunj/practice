# %%
import pandas as pd

# %%
df=pd.read_excel('C:\\Users\\shash\\Downloads\\Mobile Tag Update Test Data.xlsx')

# %%
df.to_dict(orient='series')
# Out:
# {'Unnamed: 0': 0     NaN
#  1     NaN
#  2     NaN
#  3     NaN
#  4     NaN
#  5     NaN
#  6     NaN
#  7     NaN
#  8     NaN
#  9     NaN
#  10    NaN
#  11    NaN
#  12    NaN
#  13    NaN
#  14    NaN
#  15    NaN
#  16    NaN
#  17    NaN
#  18    NaN
#  19    NaN
#  20    NaN
#  21    NaN
#  22    NaN
#  23    NaN
#  24    NaN
#  25    NaN
#  26    NaN
#  27    NaN
#  28    NaN
#  29    NaN
#         ..
#  178   NaN
#  179   NaN
#  180   NaN
#  181   NaN
#  182   NaN
#  183   NaN
#  184   NaN
#  185   NaN
#  186   NaN
#  187   NaN
#  188   NaN
#  189   NaN
#  190   NaN
#  191   NaN
#  192   NaN
#  193   NaN
#  194   NaN
#  195   NaN
#  196   NaN
#  197   NaN
#  198   NaN
#  199   NaN
#  200   NaN
#  201   NaN
#  202   NaN
#  203   NaN
#  204   NaN
#  205   NaN
#  206   NaN
#  207   NaN
#  Name: Unnamed: 0, Length: 208, dtype: float64, 'Publisher Type': 0     NaN
#  1     NaN
#  2     NaN
#  3     NaN
#  4     NaN
#  5     NaN
#  6     NaN
#  7     NaN
#  8     NaN
# ...
