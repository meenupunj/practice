# %%
***settings***
library  SeleniumLibrary

# %%
***variables***
${path_for_city}  //input[@class="react-autosuggest__input react-autosuggest__input--open"]
${login using facebook}  xpath://div[@class="makeFlex fbLoginBtn flexOne appendRight20"]

# %%
***Test cases***
Open Browser To Login Page
    Open Browser    https://www.makemytrip.com/    FireFox
    Maximize Browser Window
    
    ##handling popup login window
    click element  xpath://div[@class="loginModal displayBlock modalLogin dynHeight personal "]
    
    ## selecting hotel tab and entering city
    click link   xpath:/html/body/div/div/div[1]/div[1]/div[2]/div/div/nav/ul/li[2]/a
    sleep  5
    #input Text  xpath://input[@id="city"]   goa
    #click element   ${path_for_city}
    #select from input by id  city  goa
    #sleep  5
    
    ##entering checkin and checkout dates
    click element   xpath://input[@id="checkin"]
    #checkin date
    click element   xpath://div[@class="DayPicker-Day DayPicker-Day--disabled DayPicker-Day--outside"][1]
    #checkout date
    click element   xpath://div[@class="DayPicker-Day DayPicker-Day--disabled DayPicker-Day--outside"][2]
    #select room
    #click element   xpath://div[@class="addRooomDetails"]
    click element   xpath://input[@id="guest"]
    click element   xpath://li[@data-cy="adults-3"]
    click element   xpath://li[@data-cy="children-1"]click element   xpath://div[@class="DayPicker-Day DayPicker-Day--disabled DayPicker-Day--outside"]
    click element   xpath://div[@class="ageSelectBox"]
    click element   xpath://li[@data-cy="childAgeValue-3"]
    #click apply button    id:APPLY
    click button    xpath://button[@class="primaryBtn btnApply"]
    
    #click search button
    click button    xpath://button[@id="hsw_search_button"]
    
    Set Selenium Speed    3
    #click element   xpath://*[@id="search-icon-legacy"]
    sleep 3
    #close Browser
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></
# ...

# %%
***Keywords***

# %%
/html/body/div/div/div[2]/div/div/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div/ul/li[1]/div/div/div

# %%
/html/body/div/div/div[2]/div/div/div[2]/div/div[1]/div[1]/div[1]/div/div/div/div/div[1]/ul/li[1]/div/div/div

# %%
//div[@class="DayPicker-Week"]/div[2]
